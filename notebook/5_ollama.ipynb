# %%
from langchain_ollama import ChatOllama

llm=ChatOllama(model='mistral')

llm.invoke('hi')
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[1], line 5
#       1 from langchain_ollama import ChatOllama
#       2
#       3 llm=ChatOllama(model='mistral')
#       4
# ----> 5 llm.invoke('hi')
#
# File d:\PYTHON\GEN AI\GeniAI-Projects\env\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
# ...
