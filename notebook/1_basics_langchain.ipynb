# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI


llm=ChatOpenAI(model='gpt-5-nano')

# %%
# from langchain_community.llms import Ollama
from langchain_ollama import OllamaLLM

model=OllamaLLM(model='llama3')

model.invoke('Tell me about GenAI')
# Out:
# "GenAI!\n\nGenAI is an innovative artificial intelligence (AI) platform that leverages the power of generative models to create a wide range of applications. The company, GenAI, has developed a proprietary technology that enables the creation of AI-driven products and services across various industries, including entertainment, education, healthcare, and more.\n\nWhat sets GenAI apart is its focus on generating high-quality content using machine learning algorithms. This allows for the creation of customized experiences, personalized recommendations, and innovative solutions that were previously unimaginable.\n\nSome of the key features of GenAI's technology include:\n\n1. **Generative Models**: GenAI uses advanced generative models, such as GANs (Generative Adversarial Networks) and VAEs (Variational Autoencoders), to generate content that is indistinguishable from human-created work.\n2. **Content Generation**: The platform can generate a wide range of content types, including text, images, videos, audio files, and more.\n3. **Customization**: GenAI's technology allows for customization based on user preferences, behavior, and context, enabling personalized experiences and recommendations.\n4. **Innovation**: The platform is designed to foster innovation by providing developers with tools and APIs to create new applications and services.\n\nApplications of GenAI's technology include:\n\n1. **Content Creation**: Generate high-quality content for various industries, such as entertainment, publishing, and marketing.\n2. **Personalized Recommendations**: Develop personalized product recommendations for e-commerce platforms, music streaming services, and more.\n3. **Virtual Assistants**: Create AI-powered virtual assistants that can understand natural language and respond accordingly.\n4. **Healthcare**: Generate personalized treatment plans, medical summaries, and patient reports based on medical data.\n\nGenAI has gained significant attention in the industry due to its innovative approach and impressive results. If you're interested in learning more about GenAI or exploring potential applications of their technology, I'd be happy to help!"

# %%
from IPython.display import display, Markdown

prompts=[
    ('system','youre a python developer'),
    ('user','how to sort an array')
]

#  [(system)-> what you want to make ai, ai-> ai reply given last time , user-.my qusetion ]


result=llm.invoke(prompts)
display(Markdown(result.content))
# Out:
# In Python, you typically sort a list (often called an array) with two main options:
#
# - sorted(iterable) → returns a new sorted list (does not modify the original)
# - list.sort() → sorts the list in place and returns None
#
# Key examples:
#
# - Simple ascending sort (new list):
#   arr = [3, 1, 4, 1, 5]
#   sorted_arr = sorted(arr)  # [1, 1, 3, 4, 5]
#
# - In-place sort (modifies the original list):
#   arr.sort()  # arr is now [1, 1, 3, 4, 5]
#
# - Descending sort:
#   sorted_arr = sorted(arr, reverse=True)  # [5, 4, 3, 1, 1]
#
# - Sort with a key (e.g., sort strings by length):
#   words = ['apple', 'fig', 'banana']
#   sorted_by_len = sorted(words, key=len)  # ['fig', 'apple', 'banana']
#
# - Case-insensitive sort:
#   words = ['Banana', 'apple', 'Cherry']
#   sorted_case_insensitive = sorted(words, key=str.lower)
#
# - Sorting a list of dictionaries or objects by a field/attribute:
#   people = [{'name': 'Alice', 'age': 30}, {'name': 'Bob', 'age': 25}]
#   sorted_by_age = sorted(people, key=lambda p: p['age'])
#
# Notes and tips:
#
# - sorted(...) returns a new list; original list remains unchanged.
# - list.sort(...) sorts in place; returns None.
# - The sort is stable in Python (equal keys preserve original order).
# - Time complexity is typically O(n log n).
#
# If you’re using NumPy instead of a Python list, you can sort arrays like this:
#
# - import numpy as np
#   a = np.array([3, 1, 4])
#   b = np.sort(a)  # returns a sorted copy
#   a.sort()        # sorts in place (on the original array)
#
# If you share a quick sample of your data and how you want it sorted (by value, by length, by a field, etc.), I can tailor the exact code.
